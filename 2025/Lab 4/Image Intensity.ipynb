# %%
import numpy as np
import skimage as ski

# %%
cameraMan = ski.data.camera()
print(cameraMan.shape)
ski.io.imshow(cameraMan)
# Out:
# (512, 512)

# %%
L = np.iinfo(cameraMan.dtype).max
L
# Out:
# 255

# %%
inverted  = ski.util.invert(cameraMan)
ski.io.imshow(inverted)

# %%
LogImage = np.log1p(cameraMan)
ski.io.imshow(LogImage.astype(np.uint8))

# %%
LogImage/=np.max(LogImage)
ski.io.imshow(LogImage)

# %%
newLog =  255/(np.log(1 + np.max(cameraMan))) * np.log(1 + cameraMan)
ski.io.imshow(newLog.astype(np.uint8))fedddvrr
# Out:
# C:\Users\baher\AppData\Local\Temp\ipykernel_1752\2187041656.py:1: RuntimeWarning: divide by zero encountered in log
#   newLog =  255/(np.log(1 + np.max(cameraMan))) * np.log(1 + cameraMan)
# C:\Users\baher\AppData\Local\Temp\ipykernel_1752\2187041656.py:2: RuntimeWarning: invalid value encountered in cast
#   ski.io.imshow(newLog.astype(np.uint8))

# %%
image = ski.io.imread('[.png', as_gray=True)
ski.io.imshow(image)

# %%
image.shape
# Out:
# (469, 480)
